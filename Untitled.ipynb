# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, SimpleRNN, GRU
import matplotlib.pyplot as plt

# Load your data
data = pd.read_csv('data.csv')  # Replace with your file
data['date'] = pd.to_datetime(data['date'])
data = data[['date', 'warehouse_capacity', 'truck_capacity']]
data.set_index('date', inplace=True)

# Normalize data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# %%
# Prepare sequences for LSTM
def create_sequences(data, sequence_length):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i+sequence_length])
        y.append(data[i+sequence_length])
    return np.array(X), np.array(y)

sequence_length = 5  # Look back 30 days
X, y = create_sequences(scaled_data, sequence_length)

# %%
# Split into train and test sets
train_size = int(len(X) * 0.8)
X_train, y_train = X[:train_size], y[:train_size]
X_test, y_test = X[train_size:], y[train_size:]

# %%
# Build LSTM model
def lstm_model():
    model = Sequential([
        LSTM(50, activation='relu', return_sequences = True, input_shape=(X_train.shape[1], X_train.shape[2])),
        Dropout(0.1),
        LSTM(200, activation='relu'),
        Dropout(0.1),
        Dense(y_train.shape[1])  # Output layer
    ])

    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Build RNN model
def rnn_model():
    model = Sequential([
        SimpleRNN(50, activation='relu', return_sequences = True, input_shape=(X_train.shape[1], X_train.shape[2])),
        Dropout(0.1),
        SimpleRNN(200, activation='relu'),
        Dropout(0.1),
        Dense(y_train.shape[1])  # Output layer
    ])

    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Build GRU model
def gru_model():
    model = Sequential([
        GRU(50, activation='relu', return_sequences = True, input_shape=(X_train.shape[1], X_train.shape[2])),
        Dropout(0.1),
        GRU(200, activation='relu'),
        Dropout(0.1),
        Dense(y_train.shape[1])  # Output layer
    ])

    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
epochs=100
batch_size=32

# %%
model_lstm = lstm_model()
history = model_lstm.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# c:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 0.1193 - val_loss: 0.0147
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0053 - val_loss: 0.0036
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 8/100
# ...

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 6))
plt.plot(train_loss, label='Training Loss', color='blue')
plt.plot(val_loss, label='Val Loss', color='red')
plt.title('Loss Over Epochs', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
# plt.ylabel('Loss', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.show()

# %%
def predict(model):
    # Predict the next 14 days
    last_sequence = scaled_data[-sequence_length:]
    predicted = []
    
    for _ in range(14):
        prediction = model.predict(last_sequence[np.newaxis, :, :])
        predicted.append(prediction[0])
        last_sequence = np.vstack((last_sequence[1:], prediction))
    
    predicted = scaler.inverse_transform(predicted)


    # Display predictions
    predicted_df = pd.DataFrame(predicted, columns=data.columns)
    predicted_df.index = pd.date_range(start=data.index[-1] + pd.Timedelta(days=1), periods=14)
    predicted_df['warehouse_capacity'] = predicted_df['warehouse_capacity'].astype(int)
    predicted_df['truck_capacity'] = predicted_df['truck_capacity'].astype(int)
    # print(predicted_df)
    return predicted_df

# %%
predicted_df = predict(model_lstm)

# Extract the last 30 days of data
last_30_days = data.iloc[-30:]

# Plot the last 30 days of data
plt.figure(figsize=(12, 6))

# Plot the original data (last 30 days)
plt.plot(last_30_days.index, last_30_days['warehouse_capacity'], label='Last 30 Days - Warehouse Capacity', color='blue')
plt.plot(last_30_days.index, last_30_days['truck_capacity'], label='Last 30 Days - Truck Capacity', color='green')

# Plot the predictions
plt.plot(predicted_df.index, predicted_df['warehouse_capacity'], label='Predicted Warehouse Capacity', linestyle='--', color='red')
plt.plot(predicted_df.index, predicted_df['truck_capacity'], label='Predicted Truck Capacity', linestyle='--', color='orange')

plt.title('Last 30 Days Data and Predictions')
plt.xlabel('Date')
plt.ylabel('Capacity')
plt.legend()
plt.grid()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
model_lstm.save('model_lstm.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model_rnn = rnn_model()
history = model_rnn.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# c:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0479 - val_loss: 0.0045
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - val_loss: 0.0041
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - val_loss: 0.0044
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0040 - val_loss: 0.0036
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - val_loss: 0.0070
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - val_loss: 0.0050
# Epoch 8/100
# ...

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 6))
plt.plot(train_loss, label='Training Loss', color='blue')
plt.plot(val_loss, label='Val Loss', color='red')
plt.title('Loss Over Epochs', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
# plt.ylabel('Loss', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.show()

# %%
predicted_df = predict(model_rnn)

# Plot the last 30 days of data
plt.figure(figsize=(12, 6))

# Plot the original data (last 30 days)
plt.plot(last_30_days.index, last_30_days['warehouse_capacity'], label='Last 30 Days - Warehouse Capacity', color='blue')
plt.plot(last_30_days.index, last_30_days['truck_capacity'], label='Last 30 Days - Truck Capacity', color='green')

# Plot the predictions
plt.plot(predicted_df.index, predicted_df['warehouse_capacity'], label='Predicted Warehouse Capacity', linestyle='--', color='red')
plt.plot(predicted_df.index, predicted_df['truck_capacity'], label='Predicted Truck Capacity', linestyle='--', color='orange')

plt.title('Last 30 Days Data and Predictions')
plt.xlabel('Date')
plt.ylabel('Capacity')
plt.legend()
plt.grid()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
model_rnn.save('model_rnn.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model_gru = gru_model()
history = model_gru.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# c:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - loss: 0.0881 - val_loss: 0.0089
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0052 - val_loss: 0.0032
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0036 - val_loss: 0.0031
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0036 - val_loss: 0.0031
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 8/100
# ...

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 6))
plt.plot(train_loss, label='Training Loss', color='blue')
plt.plot(val_loss, label='Val Loss', color='red')
plt.title('Loss Over Epochs', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
# plt.ylabel('Loss', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.show()

# %%
predicted_df = predict(model_gru)

# Plot the last 30 days of data
plt.figure(figsize=(12, 6))

# Plot the original data (last 30 days)
plt.plot(last_30_days.index, last_30_days['warehouse_capacity'], label='Last 30 Days - Warehouse Capacity', color='blue')
plt.plot(last_30_days.index, last_30_days['truck_capacity'], label='Last 30 Days - Truck Capacity', color='green')

# Plot the predictions
plt.plot(predicted_df.index, predicted_df['warehouse_capacity'], label='Predicted Warehouse Capacity', linestyle='--', color='red')
plt.plot(predicted_df.index, predicted_df['truck_capacity'], label='Predicted Truck Capacity', linestyle='--', color='orange')

plt.title('Last 30 Days Data and Predictions')
plt.xlabel('Date')
plt.ylabel('Capacity')
plt.legend()
plt.grid()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
model_gru.save('model_gru.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
